# %% [markdown]
# ## EVALUACIÓN MÓDULO 3. ANÁLISIS DE DATOS
#
# Los datos que se proporciona consisten en dos conjuntos de archivos que, en conjunto, describen el
# comportamiento de los clientes dentro de un programa de lealtad de una aerolínea.

# %% [markdown]
# ### PASO 1. IMPORTACIÓN LIBRERÍAS

# %%
import pandas as pd
import numpy as np

#Viualización completa del DataFrame (todas sus columnas)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### PASO 2. LECTURA DE ARCHIVOS

# %% [markdown]
# ### 2.1. ARCHIVO INFORMACIÓN CLIENTES

# %%
df_clientes = pd.read_csv('../files/Customer Loyalty History.csv')
# no necesitamos usar index_col = 0

# %%
df_clientes.sample(5)
# Out:
#        Loyalty Number Country      Province         City Postal Code  Gender  \
# 15953          243696  Canada       Ontario      Toronto     P1J 8T7    Male
# 7633           779573  Canada       Ontario      Toronto     M2M 7K8  Female
# 16630          605723  Canada       Ontario  Thunder Bay     K8T 5M5    Male
# 12970          407173  Canada       Ontario      Trenton     K8V 4B2  Female
# 3546           243005  Canada  Newfoundland   St. John's     A1C 6H9    Male
#
#       Education   Salary Marital Status Loyalty Card       CLV  \
# 15953  Bachelor  85211.0        Married         Star  13158.37
# 7633   Bachelor  72563.0       Divorced         Nova   7433.82
# 16630   College      NaN        Married         Star  30205.01
# 12970   College      NaN         Single         Star   4692.66
# 3546    College      NaN         Single       Aurora  14428.87
#
#       Enrollment Type  Enrollment Year  Enrollment Month  Cancellation Year  \
# 15953        Standard             2013                 7                NaN
# 7633         Standard             2013                 2                NaN
# 16630        Standard             2014                 1                NaN
# 12970        Standard             2013                 3                NaN
# 3546         Standard             2013                 2                NaN
#
#        Cancellation Month
# 15953                 NaN
# 7633                  NaN
# 16630                 NaN
# 12970                 NaN
# 3546                  NaN

# %%
df_clientes.columns
# Out:
# Index(['Loyalty Number', 'Country', 'Province', 'City', 'Postal Code',
#        'Gender', 'Education', 'Salary', 'Marital Status', 'Loyalty Card',
#        'CLV', 'Enrollment Type', 'Enrollment Year', 'Enrollment Month',
#        'Cancellation Year', 'Cancellation Month'],
#       dtype='object')

# %% [markdown]
# ### Renombramos las columnas para poder trabajar con ellas

# %%
df_clientes.columns = df_clientes.columns.str.replace(" ", "_")

# %%
# Comprobamos
df_clientes.columns
# Out:
# Index(['Loyalty_Number', 'Country', 'Province', 'City', 'Postal_Code',
#        'Gender', 'Education', 'Salary', 'Marital_Status', 'Loyalty_Card',
#        'CLV', 'Enrollment_Type', 'Enrollment_Year', 'Enrollment_Month',
#        'Cancellation_Year', 'Cancellation_Month'],
#       dtype='object')

# %% [markdown]
# ### Miramos el tamaño de nuestro data frame

# %%
df_clientes.shape
# Out:
# (16737, 16)

# %% [markdown]
# ### Visualizamos la información general de nuestro data frame

# %%
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16737 entries, 0 to 16736
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Loyalty_Number      16737 non-null  int64
#  1   Country             16737 non-null  object
#  2   Province            16737 non-null  object
#  3   City                16737 non-null  object
#  4   Postal_Code         16737 non-null  object
#  5   Gender              16737 non-null  object
#  6   Education           16737 non-null  object
#  7   Salary              12499 non-null  float64
#  8   Marital_Status      16737 non-null  object
#  9   Loyalty_Card        16737 non-null  object
#  10  CLV                 16737 non-null  float64
#  11  Enrollment_Type     16737 non-null  object
#  12  Enrollment_Year     16737 non-null  int64
#  13  Enrollment_Month    16737 non-null  int64
#  14  Cancellation_Year   2067 non-null   float64
#  15  Cancellation_Month  2067 non-null   float64
# dtypes: float64(4), int64(3), object(9)
# memory usage: 2.0+ MB

# %%
df_clientes.describe().T
# Out:
#                       count           mean            std        min  \
# Loyalty_Number      16737.0  549735.880445  258912.132453  100018.00
# Salary              12499.0   79245.609409   35008.297285  -58486.00
# CLV                 16737.0    7988.896536    6860.982280    1898.01
# Enrollment_Year     16737.0    2015.253211       1.979111    2012.00
# Enrollment_Month    16737.0       6.669116       3.398958       1.00
# Cancellation_Year    2067.0    2016.503145       1.380743    2013.00
# Cancellation_Month   2067.0       6.962748       3.455297       1.00
#
#                           25%        50%        75%        max
# Loyalty_Number      326603.00  550434.00  772019.00  999986.00
# Salary               59246.50   73455.00   88517.50  407228.00
# CLV                   3980.84    5780.18    8940.58   83325.38
# Enrollment_Year       2014.00    2015.00    2017.00    2018.00
# Enrollment_Month         4.00       7.00      10.00      12.00
# Cancellation_Year     2016.00    2017.00    2018.00    2018.00
# Cancellation_Month       4.00       7.00      10.00      12.00

# %% [markdown]
# #### Duplicados

# %%
df_clientes.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Nulos

# %%
df_clientes.isnull().sum()
# Out:
# Loyalty_Number            0
# Country                   0
# Province                  0
# City                      0
# Postal_Code               0
# Gender                    0
# Education                 0
# Salary                 4238
# Marital_Status            0
# Loyalty_Card              0
# CLV                       0
# Enrollment_Type           0
# Enrollment_Year           0
# Enrollment_Month          0
# Cancellation_Year     14670
# Cancellation_Month    14670
# dtype: int64

# %% [markdown]
# ##### Porcentaje de nulos

# %%
df_clientes.isnull().sum()/df_clientes.shape[0]*100
# Out:
# Loyalty_Number         0.000000
# Country                0.000000
# Province               0.000000
# City                   0.000000
# Postal_Code            0.000000
# Gender                 0.000000
# Education              0.000000
# Salary                25.321145
# Marital_Status         0.000000
# Loyalty_Card           0.000000
# CLV                    0.000000
# Enrollment_Type        0.000000
# Enrollment_Year        0.000000
# Enrollment_Month       0.000000
# Cancellation_Year     87.650117
# Cancellation_Month    87.650117
# dtype: float64

# %% [markdown]
# ##### Generamos dataset con los clientes que han cursado baja en la aerolínea

# %%
df_clientes[df_clientes[['Cancellation_Year', 'Cancellation_Month']].notnull().all(axis=1)]
# Out:
#        Loyalty_Number Country          Province            City Postal_Code  \
# 2              429460  Canada  British Columbia       Vancouver     V6E 3D9
# 19             354730  Canada     New Brunswick     Fredericton     E3B 2H2
# 31             201574  Canada           Ontario          Ottawa     K1F 2R2
# 39             834891  Canada  British Columbia       Vancouver     V5R 1W3
# 45             733338  Canada           Ontario     Thunder Bay     K8T 5M5
# ...               ...     ...               ...             ...         ...
# 16706          409984  Canada             Yukon      Whitehorse     Y2K 6R0
# 16713          969719  Canada  British Columbia  West Vancouver     V6V 8Z3
# 16718          795743  Canada           Ontario     Thunder Bay     K8T 5M5
# 16730          672917  Canada           Ontario         Toronto     M1R 4K3
# 16736          652627  Canada          Manitoba        Winnipeg     R2C 0M5
#
#        Gender Education   Salary Marital_Status Loyalty_Card       CLV  \
# 2        Male   College      NaN         Single         Star   3839.75
# 19     Female   College      NaN        Married         Star   3885.46
# 31     Female  Bachelor  51375.0        Married         Star   3893.31
# 39     Female  Bachelor  54460.0        Married         Star   3911.12
# 45     Female  Bachelor  80697.0        Married         Star   3919.37
# ...       ...       ...      ...            ...          ...       ...
# 16706    Male   College      NaN         Single         Star   7452.23
# 16713    Male  Bachelor  88356.0        Married         Star  40235.97
# 16718    Male   College      NaN        Married         Star  43019.01
# 16730  Female  Bachelor  76778.0         Single         Star  58166.55
# 16736  Female  Bachelor  75049.0        Married         Star  83325.38
#
#       Enrollment_Type  Enrollment_Year  Enrollment_Month  Cancellation_Year  \
# 2            Standard             2014                 7             2018.0
# 19           Standard             2014                10             2018.0
# 31           Standard             2015                 4             2015.0
# 39           Standard             2017                 3             2017.0
# 45           Standard             2016                 6             2017.0
# ...               ...              ...               ...                ...
# 16706  2018 Promotion             2018                 4             2018.0
# 16713        Standard             2016                 5             2017.0
# 16718        Standard             2013                11             2014.0
# 16730        Standard             2015                 1             2015.0
# 16736        Standard             2015                12             2016.0
#
#        Cancellation_Month
# 2                     1.0
# 19                    1.0
# 31                   12.0
# 39                    4.0
# 45                    2.0
# ...                   ...
# 16706                12.0
# 16713                 1.0
# 16718                 7.0
# 16730                 9.0
# 16736                 8.0
#
# [2067 rows x 16 columns]

# %%
df_clientes_bajas = df_clientes[df_clientes[['Cancellation_Year', 'Cancellation_Month']].notnull().all(axis=1)]
#all(axis=1) → Se asegura de que ambas columnas no sean nulas en cada fila.

# %%
df_clientes_bajas.head(3)
# Out:
#     Loyalty_Number Country          Province         City Postal_Code  Gender  \
# 2           429460  Canada  British Columbia    Vancouver     V6E 3D9    Male
# 19          354730  Canada     New Brunswick  Fredericton     E3B 2H2  Female
# 31          201574  Canada           Ontario       Ottawa     K1F 2R2  Female
#
#    Education   Salary Marital_Status Loyalty_Card      CLV Enrollment_Type  \
# 2    College      NaN         Single         Star  3839.75        Standard
# 19   College      NaN        Married         Star  3885.46        Standard
# 31  Bachelor  51375.0        Married         Star  3893.31        Standard
#
#     Enrollment_Year  Enrollment_Month  Cancellation_Year  Cancellation_Month
# 2              2014                 7             2018.0                 1.0
# 19             2014                10             2018.0                 1.0
# 31             2015                 4             2015.0                12.0

# %%
df_clientes_bajas.isnull().sum()
# Out:
# Loyalty_Number          0
# Country                 0
# Province                0
# City                    0
# Postal_Code             0
# Gender                  0
# Education               0
# Salary                527
# Marital_Status          0
# Loyalty_Card            0
# CLV                     0
# Enrollment_Type         0
# Enrollment_Year         0
# Enrollment_Month        0
# Cancellation_Year       0
# Cancellation_Month      0
# dtype: int64

# %% [markdown]
# Lo guardamos en un csv

# %%
#df_clientes_bajas.to_csv('clientes_bajas.csv')

# %% [markdown]
# #### Elimino las columas de este dataset del df_clientes

# %%
df_clientes = df_clientes.drop(['Cancellation_Year', 'Cancellation_Month'],axis = 1)
#axis = 1 indica que quiero eliminar columnas,si quisiera eliminar filas usaría axis = 0

# %%
df_clientes.head(2)
# Out:
#    Loyalty_Number Country Province      City Postal_Code  Gender Education  \
# 0          480934  Canada  Ontario   Toronto     M2Z 4K1  Female  Bachelor
# 1          549612  Canada  Alberta  Edmonton     T3G 6Y6    Male   College
#
#     Salary Marital_Status Loyalty_Card      CLV Enrollment_Type  \
# 0  83236.0        Married         Star  3839.14        Standard
# 1      NaN       Divorced         Star  3839.61        Standard
#
#    Enrollment_Year  Enrollment_Month
# 0             2016                 2
# 1             2016                 3

# %%
df_clientes.isnull().sum()
# Out:
# Loyalty_Number         0
# Country                0
# Province               0
# City                   0
# Postal_Code            0
# Gender                 0
# Education              0
# Salary              4238
# Marital_Status         0
# Loyalty_Card           0
# CLV                    0
# Enrollment_Type        0
# Enrollment_Year        0
# Enrollment_Month       0
# dtype: int64

# %% [markdown]
# ### Reviamos los valores únicos de las columnas categóricas para revisar errores tipográficos

# %%
df_clientes.select_dtypes(include='O').nunique()
# Out:
# Country             1
# Province           11
# City               29
# Postal_Code        55
# Gender              2
# Education           5
# Marital_Status      3
# Loyalty_Card        3
# Enrollment_Type     2
# dtype: int64

# %% [markdown]
# #### Para ver el valor único de cada columna usamos apply y lambda y que son varios parámetros

# %%
columnas_valores = df_clientes.select_dtypes(include='O').apply(lambda x: x.unique())
columnas_valores.reset_index()
# Out:
#              index                                                  0
# 0          Country                                           [Canada]
# 1         Province  [Ontario, Alberta, British Columbia, Quebec, Y...
# 2             City  [Toronto, Edmonton, Vancouver, Hull, Whitehors...
# 3      Postal_Code  [M2Z 4K1, T3G 6Y6, V6E 3D9, P1W 1K4, J8Y 3Z5, ...
# 4           Gender                                     [Female, Male]
# 5        Education  [Bachelor, College, Master, High School or Bel...
# 6   Marital_Status                        [Married, Divorced, Single]
# 7     Loyalty_Card                               [Star, Aurora, Nova]
# 8  Enrollment_Type                         [Standard, 2018 Promotion]

# %%
#para poder visualizar todo:

for dato in columnas_valores:
    
    print(dato)
# Out:
# ['Canada']
# ['Ontario' 'Alberta' 'British Columbia' 'Quebec' 'Yukon' 'New Brunswick'
#  'Manitoba' 'Nova Scotia' 'Saskatchewan' 'Newfoundland'
#  'Prince Edward Island']
# ['Toronto' 'Edmonton' 'Vancouver' 'Hull' 'Whitehorse' 'Trenton' 'Montreal'
#  'Dawson Creek' 'Quebec City' 'Fredericton' 'Ottawa' 'Tremblant' 'Calgary'
#  'Thunder Bay' 'Whistler' 'Peace River' 'Winnipeg' 'Sudbury'
#  'West Vancouver' 'Halifax' 'London' 'Regina' 'Kelowna' "St. John's"
#  'Victoria' 'Kingston' 'Banff' 'Moncton' 'Charlottetown']
# ['M2Z 4K1' 'T3G 6Y6' 'V6E 3D9' 'P1W 1K4' 'J8Y 3Z5' 'Y2K 6R0' 'P5S 6R4'
#  'K8V 4B2' 'H2Y 2W2' 'M8Y 4K8' 'U5I 4F1' 'G1B 3L5' 'H4G 3T4' 'M2M 7K8'
#  'M2M 6J7' 'E3B 2H2' 'M1R 4K3' 'T9G 1W3' 'H2Y 4R4' 'V5R 1W3' 'P1L 8X8'
#  'K1F 2R2' 'H5Y 2S9' 'V1E 4R6' 'H2T 2J6' 'T3E 2V9' 'H2T 9K8' 'K8T 5M5'
#  'V6T 1Y8' 'P2T 6G3' 'T9O 2W2' 'V6E 3Z3' 'R6Y 4T5' 'M5V 1G5' 'V6V 8Z3'
#  'B3J 9S2' 'M5B 3E4' 'R2C 0M5' 'S6J 3G0' 'M2P 4F6' 'P1J 8T7' 'V09 2E9'
#  'A1C 6H9' 'V10 6T5' 'B3C 2M8' 'M9K 2P4' 'T4V 1D4' 'R3R 3T4' 'S1J 3C5'
#  'E1A 2A7' 'K1G 4Z0' 'H3T 8L4' 'C1A 6E8' 'H3J 5I6' 'M3R 4K8']
# ['Female' 'Male']
# ['Bachelor' 'College' 'Master' 'High School or Below' 'Doctor']
# ['Married' 'Divorced' 'Single']
# ['Star' 'Aurora' 'Nova']
# ['Standard' '2018 Promotion']

# %% [markdown]
# #### Transformación de los datos : Creamos una funcion para varias columnas

# %%
def limpiar_datos(df,columnas):
    
    for columna in columnas:
        
        df[columna]=df[columna].apply(lambda valor:str(valor).replace(' ','_'))
        #quitamos los espacios al ppo y final de cada dato y genermos_ en los espacios entre palabras.
        
    return(df)#aplicamos los resultados directamente en el df

# %%
columnas_categoricas = df_clientes.select_dtypes(include='O')
columnas_categoricas
# Out:
#       Country          Province        City Postal_Code  Gender Education  \
# 0      Canada           Ontario     Toronto     M2Z 4K1  Female  Bachelor
# 1      Canada           Alberta    Edmonton     T3G 6Y6    Male   College
# 2      Canada  British Columbia   Vancouver     V6E 3D9    Male   College
# 3      Canada           Ontario     Toronto     P1W 1K4    Male   College
# 4      Canada            Quebec        Hull     J8Y 3Z5    Male  Bachelor
# ...       ...               ...         ...         ...     ...       ...
# 16732  Canada  British Columbia   Vancouver     V6E 3Z3  Female   College
# 16733  Canada      Saskatchewan      Regina     S1J 3C5  Female  Bachelor
# 16734  Canada  British Columbia   Vancouver     V5R 1W3    Male   College
# 16735  Canada             Yukon  Whitehorse     Y2K 6R0    Male  Bachelor
# 16736  Canada          Manitoba    Winnipeg     R2C 0M5  Female  Bachelor
#
#       Marital_Status Loyalty_Card Enrollment_Type
# 0            Married         Star        Standard
# 1           Divorced         Star        Standard
# 2             Single         Star        Standard
# 3             Single         Star        Standard
# 4            Married         Star        Standard
# ...              ...          ...             ...
# 16732        Married         Star        Standard
# 16733        Married         Star        Standard
# 16734         Single         Star        Standard
# 16735        Married         Star  2018 Promotion
# 16736        Married         Star        Standard
#
# [16737 rows x 9 columns]

# %%
limpiar_datos(df_clientes,columnas_categoricas)
# Out:
#        Loyalty_Number Country          Province        City Postal_Code  \
# 0              480934  Canada           Ontario     Toronto     M2Z_4K1
# 1              549612  Canada           Alberta    Edmonton     T3G_6Y6
# 2              429460  Canada  British_Columbia   Vancouver     V6E_3D9
# 3              608370  Canada           Ontario     Toronto     P1W_1K4
# 4              530508  Canada            Quebec        Hull     J8Y_3Z5
# ...               ...     ...               ...         ...         ...
# 16732          823768  Canada  British_Columbia   Vancouver     V6E_3Z3
# 16733          680886  Canada      Saskatchewan      Regina     S1J_3C5
# 16734          776187  Canada  British_Columbia   Vancouver     V5R_1W3
# 16735          906428  Canada             Yukon  Whitehorse     Y2K_6R0
# 16736          652627  Canada          Manitoba    Winnipeg     R2C_0M5
#
#        Gender Education    Salary Marital_Status Loyalty_Card       CLV  \
# 0      Female  Bachelor   83236.0        Married         Star   3839.14
# 1        Male   College       NaN       Divorced         Star   3839.61
# 2        Male   College       NaN         Single         Star   3839.75
# 3        Male   College       NaN         Single         Star   3839.75
# 4        Male  Bachelor  103495.0        Married         Star   3842.79
# ...       ...       ...       ...            ...          ...       ...
# 16732  Female   College       NaN        Married         Star  61850.19
# 16733  Female  Bachelor   89210.0        Married         Star  67907.27
# 16734    Male   College       NaN         Single         Star  74228.52
# 16735    Male  Bachelor  -57297.0        Married         Star  10018.66
# 16736  Female  Bachelor   75049.0        Married         Star  83325.38
#
#       Enrollment_Type  Enrollment_Year  Enrollment_Month
# 0            Standard             2016                 2
# 1            Standard             2016                 3
# 2            Standard             2014                 7
# 3            Standard             2013                 2
# 4            Standard             2014                10
# ...               ...              ...               ...
# 16732        Standard             2012                12
# 16733        Standard             2014                 9
# 16734        Standard             2014                 3
# 16735  2018_Promotion             2018                 4
# 16736        Standard             2015                12
#
# [16737 rows x 14 columns]

# %% [markdown]
# #### Transformación columnas numéricas

# %%
columnas_num = df_clientes.select_dtypes('number')

# %%
columnas_num.sample(5)
# Out:
#        Loyalty_Number    Salary      CLV  Enrollment_Year  Enrollment_Month
# 2376           803252  101563.0  8024.51             2014                 5
# 1508           307785  111948.0  5926.73             2016                10
# 6419           593277       NaN  5143.87             2017                12
# 16698          909547   54567.0  5759.01             2018                 4
# 4500           777549   71038.0  2886.45             2013                 1

# %%
columnas_num.dtypes
# Out:
# Loyalty_Number        int64
# Salary              float64
# CLV                 float64
# Enrollment_Year       int64
# Enrollment_Month      int64
# dtype: object

# %% [markdown]
# Unifcamos las columnas mes y año y convertirmos al tipo de dato que corresponde teniendo en cuenta que no tenemos registro de día en fecha

# %%
df_clientes[['Enrollment_Year', 'Enrollment_Month']].sample(15)
# Out:
#        Enrollment_Year  Enrollment_Month
# 4565              2017                12
# 13042             2013                 3
# 5735              2014                12
# 7333              2018                 5
# 10527             2015                 9
# 13971             2014                 9
# 10334             2016                 8
# 8880              2017                 4
# 1456              2018                 5
# 12827             2016                 7
# 122               2015                 2
# 9415              2013                 3
# 3994              2014                11
# 14447             2016                 7
# 12051             2014                 2

# %%
df_clientes['Enrollment_Date'] = pd.to_datetime(df_clientes[['Enrollment_Year', 'Enrollment_Month']].astype(str).agg('-'.join, axis=1) + '-01')

# %% [markdown]
# Formato para no tener que registrar días, es un dato que no tenemos y por defecto añadiría 1.No es correcto

# %%
df_clientes['Enrollment_Date'] = df_clientes['Enrollment_Date'].dt.to_period('M')

# %%
df_clientes['Enrollment_Date']
# Out:
# 0        2016-02
# 1        2016-03
# 2        2014-07
# 3        2013-02
# 4        2014-10
#           ...
# 16732    2012-12
# 16733    2014-09
# 16734    2014-03
# 16735    2018-04
# 16736    2015-12
# Name: Enrollment_Date, Length: 16737, dtype: period[M]

# %% [markdown]
# Eliminamos las columnas que teníamos separadas

# %%
df_clientes = df_clientes.drop(columns = ['Enrollment_Year', 'Enrollment_Month'])

# %% [markdown]
# Comprobamos

# %%
df_clientes.head()
# Out:
#    Loyalty_Number Country          Province       City Postal_Code  Gender  \
# 0          480934  Canada           Ontario    Toronto     M2Z_4K1  Female
# 1          549612  Canada           Alberta   Edmonton     T3G_6Y6    Male
# 2          429460  Canada  British_Columbia  Vancouver     V6E_3D9    Male
# 3          608370  Canada           Ontario    Toronto     P1W_1K4    Male
# 4          530508  Canada            Quebec       Hull     J8Y_3Z5    Male
#
#   Education    Salary Marital_Status Loyalty_Card      CLV Enrollment_Type  \
# 0  Bachelor   83236.0        Married         Star  3839.14        Standard
# 1   College       NaN       Divorced         Star  3839.61        Standard
# 2   College       NaN         Single         Star  3839.75        Standard
# 3   College       NaN         Single         Star  3839.75        Standard
# 4  Bachelor  103495.0        Married         Star  3842.79        Standard
#
#   Enrollment_Date
# 0         2016-02
# 1         2016-03
# 2         2014-07
# 3         2013-02
# 4         2014-10

# %% [markdown]
# Revisamos la columna salary que tiene que ser Integer y no contener valores negativos

# %%
df_clientes['Salary']
# Out:
# 0         83236.0
# 1             NaN
# 2             NaN
# 3             NaN
# 4        103495.0
#            ...
# 16732         NaN
# 16733     89210.0
# 16734         NaN
# 16735    -57297.0
# 16736     75049.0
# Name: Salary, Length: 16737, dtype: float64

# %% [markdown]
# Tenemos valores negtivos

# %%
df_clientes['Salary'] = df_clientes['Salary'].abs()
# los convertimos todos a datos absolutos ya que por coherencia con el dato tiene sentido hacerlo así

# %% [markdown]
# Comprobamos

# %%
df_clientes['Salary']
# Out:
# 0         83236.0
# 1             NaN
# 2             NaN
# 3             NaN
# 4        103495.0
#            ...
# 16732         NaN
# 16733     89210.0
# 16734         NaN
# 16735     57297.0
# 16736     75049.0
# Name: Salary, Length: 16737, dtype: float64

# %% [markdown]
# Reviso los valores nulos

# %%
df_clientes['Salary'].isnull().sum()/df_clientes.shape[0]*100
# Out:
# 25.321144769074504

# %%
estadisticos_nulos = np.round(df_clientes['Salary'].describe(),2)
estadisticos_nulos
# Out:
# count     12499.00
# mean      79359.34
# std       34749.69
# min        9081.00
# 25%       59246.50
# 50%       73455.00
# 75%       88517.50
# max      407228.00
# Name: Salary, dtype: float64

# %% [markdown]
# Para poder comparar tras la importación de nulos

# %%
media_original = df_clientes['Salary'].mean()
print(f'La media de salarios con valores nulos es de {np.round(media_original,2)}')
# Out:
# La media de salarios con valores nulos es de 79359.34

# %% [markdown]
# Tras estudiar los datos estadísticos y teniendo en cuenta el 25% de nulos, voy a reemplazar estos datos nulos por la mediana de los datos. Dado que hay valores de dispersión creo mejor decisión optar por la mediana que por la media.

# %%
#Cálculo:
#mediana_salary = df_clientes['Salary'].median()

# Reemplazo de valores nulos con la mediana
#df_clientes['Salary'] = df_clientes['Salary'].fillna(mediana_salary)

# %% [markdown]
# Comprobamos

# %%
df_clientes['Salary'].isnull().sum()
# Out:
# 4238

# %% [markdown]
# Comprobamos de nuevo los estadísticos para comprobar el reemplazo de nulos no suponga un impacto irreal en el balance general de la columna

# %%
#estadisticos= np.round(df_clientes['Salary'].describe(),2)
#estadisticos

# %%
#media_importacion = df_clientes['Salary'].mean()
#print(f'La media de salarios sin valores nulos es de {np.round(media_importacion,2)}')

# %%
#desviacion_media = media_importacion -media_original
#print(f'La desviación originada tras la importación de nulos en el dato de la media de salarios es de {np.round(desviacion_media,2)}')

# %% [markdown]
# #### Uso del Método KNN

# %%
from sklearn.impute import KNNImputer

# %%
# Creamos el objeto KNNImputer
knn_imputer = KNNImputer(n_neighbors=2)  

# Aplicar el imputador en los datos.
df_clientes_imputado = df_clientes.copy()  # Hacemos una copia para mantener los datos originales
df_clientes_imputado['Salary'] = knn_imputer.fit_transform(df_clientes_imputado[['Salary']])

# Ver los resultados
print(df_clientes_imputado['Salary'])
# Out:
# 0         83236.000000
# 1         79359.340907
# 2         79359.340907
# 3         79359.340907
# 4        103495.000000
#              ...
# 16732     79359.340907
# 16733     89210.000000
# 16734     79359.340907
# 16735     57297.000000
# 16736     75049.000000
# Name: Salary, Length: 16737, dtype: float64

# %%
print(df_clientes_imputado['Salary'].isnull().sum())
# Out:
# 0

# %%
df_clientes_imputado.describe().T
# Out:
#                   count           mean            std        min        25%  \
# Loyalty_Number  16737.0  549735.880445  258912.132453  100018.00  326603.00
# Salary          16737.0   79359.340907   30029.311812    9081.00   63899.00
# CLV             16737.0    7988.896536    6860.982280    1898.01    3980.84
#
#                           50%        75%        max
# Loyalty_Number  550434.000000  772019.00  999986.00
# Salary           79359.340907   82940.00  407228.00
# CLV               5780.180000    8940.58   83325.38

# %% [markdown]
# Coprobamos aún no hemos sobreescrito en el df_clientes

# %%
df_clientes['Salary'].isnull().sum()
# Out:
# 4238

# %%
df_clientes.describe().T
# Out:
#                   count           mean            std        min        25%  \
# Loyalty_Number  16737.0  549735.880445  258912.132453  100018.00  326603.00
# Salary          12499.0   79359.340907   34749.691464    9081.00   59246.50
# CLV             16737.0    7988.896536    6860.982280    1898.01    3980.84
#
#                       50%        75%        max
# Loyalty_Number  550434.00  772019.00  999986.00
# Salary           73455.00   88517.50  407228.00
# CLV               5780.18    8940.58   83325.38

# %% [markdown]
# ### Tras analizar ambos enfoques tiene mayor sentido usar el método KNN que mantiene los datos estadísticos de la medi, min y max exactamente iguales. Comento el código anterior para que no sea efectivo

# %% [markdown]
# Sobreescribimos

# %%
df_clientes['Salary'] = df_clientes_imputado['Salary']

# %%
df_clientes['Salary'].isnull().sum()
# Out:
# 0

# %%
df_clientes['Salary'].describe()
# Out:
# count     16737.000000
# mean      79359.340907
# std       30029.311812
# min        9081.000000
# 25%       63899.000000
# 50%       79359.340907
# 75%       82940.000000
# max      407228.000000
# Name: Salary, dtype: float64

# %% [markdown]
# Terminamos transformación de la columna convirtiendo el tipo de dato a INT

# %%
df_clientes['Salary'] = df_clientes['Salary'].astype(int)

# %%
df_clientes['Salary'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# ### ÚLTIMA REVISIÓN LIMPIEZA DF_CLIENTES

# %%
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16737 entries, 0 to 16736
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Loyalty_Number   16737 non-null  int64
#  1   Country          16737 non-null  object
#  2   Province         16737 non-null  object
#  3   City             16737 non-null  object
#  4   Postal_Code      16737 non-null  object
#  5   Gender           16737 non-null  object
#  6   Education        16737 non-null  object
#  7   Salary           16737 non-null  int64
#  8   Marital_Status   16737 non-null  object
#  9   Loyalty_Card     16737 non-null  object
#  10  CLV              16737 non-null  float64
#  11  Enrollment_Type  16737 non-null  object
#  12  Enrollment_Date  16737 non-null  period[M]
# dtypes: float64(1), int64(2), object(9), period[M](1)
# memory usage: 1.7+ MB

# %%
df_clientes.sample(10)
# Out:
#        Loyalty_Number Country          Province          City Postal_Code  \
# 16277          945765  Canada          Manitoba      Winnipeg     R2C_0M5
# 15687          231592  Canada            Quebec      Montreal     H2Y_4R4
# 11688          136334  Canada            Quebec      Montreal     H2Y_2W2
# 12449          943068  Canada          Manitoba      Winnipeg     R2C_0M5
# 6049           718887  Canada            Quebec      Montreal     H2T_2J6
# 2771           769361  Canada      Saskatchewan        Regina     S6J_3G0
# 13664          825464  Canada            Quebec      Montreal     H2T_2J6
# 69             112522  Canada           Alberta   Peace_River     T9O_2W2
# 164            164429  Canada  British_Columbia  Dawson_Creek     U5I_4F1
# 9979           242203  Canada  British_Columbia     Vancouver     V5R_1W3
#
#        Gender Education  Salary Marital_Status Loyalty_Card       CLV  \
# 16277    Male   College   79359       Divorced         Star  17497.52
# 15687  Female  Bachelor   86667        Married         Star  10760.18
# 11688  Female  Bachelor   80541        Married         Star   2717.78
# 12449  Female   College   79359       Divorced         Star   3833.07
# 6049     Male   College   79359         Single         Nova   4734.26
# 2771     Male  Bachelor   76723        Married       Aurora   8828.38
# 13664    Male   College   79359        Married         Nova   2767.50
# 69       Male  Bachelor   49846        Married       Aurora   5636.74
# 164    Female  Bachelor   57852         Single         Star   4169.36
# 9979     Male    Master  127574        Married         Star   2227.07
#
#       Enrollment_Type Enrollment_Date
# 16277        Standard         2015-11
# 15687        Standard         2016-05
# 11688        Standard         2016-04
# 12449        Standard         2013-01
# 6049         Standard         2014-03
# 2771         Standard         2013-08
# 13664  2018_Promotion         2018-02
# 69     2018_Promotion         2018-02
# 164          Standard         2012-09
# 9979         Standard         2014-05

# %% [markdown]
# Elimino columna Country ya que vemos todos los clientes son de Canada

# %%
df_clientes['Country'].unique()
# Out:
# array(['Canada'], dtype=object)

# %%
df_clientes = df_clientes.drop('Country', axis=1)

# %%
df_clientes.head(1)
# Out:
#    Loyalty_Number Province     City Postal_Code  Gender Education  Salary  \
# 0          480934  Ontario  Toronto     M2Z_4K1  Female  Bachelor   83236
#
#   Marital_Status Loyalty_Card      CLV Enrollment_Type Enrollment_Date
# 0        Married         Star  3839.14        Standard         2016-02

# %% [markdown]
# Añado el símbolo de la monead de Canadá, aunque este dato sería conveniente confirmarlo con la empresa previamente.

# %%
df_clientes = df_clientes.rename(columns = {'Salary':'Salary_$'})

# %%
df_clientes.head()
# Out:
#    Loyalty_Number          Province       City Postal_Code  Gender Education  \
# 0          480934           Ontario    Toronto     M2Z_4K1  Female  Bachelor
# 1          549612           Alberta   Edmonton     T3G_6Y6    Male   College
# 2          429460  British_Columbia  Vancouver     V6E_3D9    Male   College
# 3          608370           Ontario    Toronto     P1W_1K4    Male   College
# 4          530508            Quebec       Hull     J8Y_3Z5    Male  Bachelor
#
#    Salary_$ Marital_Status Loyalty_Card      CLV Enrollment_Type  \
# 0     83236        Married         Star  3839.14        Standard
# 1     79359       Divorced         Star  3839.61        Standard
# 2     79359         Single         Star  3839.75        Standard
# 3     79359         Single         Star  3839.75        Standard
# 4    103495        Married         Star  3842.79        Standard
#
#   Enrollment_Date
# 0         2016-02
# 1         2016-03
# 2         2014-07
# 3         2013-02
# 4         2014-10

# %% [markdown]
# Guardo como csv limpio

# %%
df_clientes.to_csv('clientes_limpio.csv')

# %% [markdown]
# ### 2.2. ARCHIVO Customer Flight Activity.csv

# %%
df_vuelos = pd.read_csv('../files/Customer Flight Activity.csv')
# no necesitamos usar index_col = 0

# %%
df_vuelos.head()
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0

# %%
df_vuelos.columns
# Out:
# Index(['Loyalty Number', 'Year', 'Month', 'Flights Booked',
#        'Flights with Companions', 'Total Flights', 'Distance',
#        'Points Accumulated', 'Points Redeemed', 'Dollar Cost Points Redeemed'],
#       dtype='object')

# %% [markdown]
# Por homogeneidad y facilitar lectura/importaciones convertimos los espacios entre palabras a _

# %%
df_vuelos.columns = df_vuelos.columns.str.replace(' ', '_')

# %%
df_vuelos.head(1)
# Out:
#    Loyalty_Number  Year  Month  Flights_Booked  Flights_with_Companions  \
# 0          100018  2017      1               3                        0
#
#    Total_Flights  Distance  Points_Accumulated  Points_Redeemed  \
# 0              3      1521               152.0                0
#
#    Dollar_Cost_Points_Redeemed
# 0                            0

# %%
df_vuelos.shape
# Out:
# (405624, 10)

# %%
df_vuelos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405624 entries, 0 to 405623
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Loyalty_Number               405624 non-null  int64
#  1   Year                         405624 non-null  int64
#  2   Month                        405624 non-null  int64
#  3   Flights_Booked               405624 non-null  int64
#  4   Flights_with_Companions      405624 non-null  int64
#  5   Total_Flights                405624 non-null  int64
#  6   Distance                     405624 non-null  int64
#  7   Points_Accumulated           405624 non-null  float64
#  8   Points_Redeemed              405624 non-null  int64
#  9   Dollar_Cost_Points_Redeemed  405624 non-null  int64
# dtypes: float64(1), int64(9)
# memory usage: 30.9 MB

# %% [markdown]
# Información que extraemos. No hay valores nulos. Por el momento el tipo de datos es correcto.
#
# Para generar un df más robusto y coherente voy a unificar los datos de mes y año en una misma columna

# %%
df_vuelos[['Year', 'Month']].sample(15)
# Out:
#         Year  Month
# 77754   2017      5
# 381878  2018     11
# 84059   2017      5
# 165590  2017     10
# 252407  2018      2
# 198155  2017     12
# 313775  2018      7
# 93111   2018      6
# 102378  2017      7
# 279268  2018      5
# 249629  2018      4
# 162218  2017     10
# 44719   2017      3
# 29797   2017      2
# 403397  2018     12

# %%
df_vuelos['Date'] = pd.to_datetime(df_vuelos[['Year', 'Month']].astype(str).agg('-'.join, axis=1) + '-01')

# %% [markdown]
# Para evitar tener día que no tenemos registro

# %%
df_vuelos['Date'] = df_vuelos['Date'].dt.to_period('M')

# %%
df_vuelos['Date']
# Out:
# 0         2017-01
# 1         2017-01
# 2         2017-01
# 3         2017-01
# 4         2017-01
#            ...
# 405619    2018-12
# 405620    2018-12
# 405621    2018-12
# 405622    2018-12
# 405623    2018-12
# Name: Date, Length: 405624, dtype: period[M]

# %% [markdown]
# Eliminamos las columnas de mes y año por separado

# %%
df_vuelos= df_vuelos.drop(columns=['Year', 'Month'])

# %% [markdown]
# Comprobamos

# %%
df_vuelos.sample(5)
# Out:
#         Loyalty_Number  Flights_Booked  Flights_with_Companions  \
# 8706            564838               0                        0
# 115832          866302               0                        0
# 143713          553558               0                        0
# 12122           743835               6                        0
# 154062          204311               0                        0
#
#         Total_Flights  Distance  Points_Accumulated  Points_Redeemed  \
# 8706                0         0                 0.0                0
# 115832              0         0                 0.0                0
# 143713              0         0                 0.0                0
# 12122               6      1188               118.0                0
# 154062              0         0                 0.0                0
#
#         Dollar_Cost_Points_Redeemed     Date
# 8706                              0  2017-01
# 115832                            0  2017-07
# 143713                            0  2017-09
# 12122                             0  2017-01
# 154062                            0  2017-10

# %%
df_vuelos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405624 entries, 0 to 405623
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Loyalty_Number               405624 non-null  int64
#  1   Flights_Booked               405624 non-null  int64
#  2   Flights_with_Companions      405624 non-null  int64
#  3   Total_Flights                405624 non-null  int64
#  4   Distance                     405624 non-null  int64
#  5   Points_Accumulated           405624 non-null  float64
#  6   Points_Redeemed              405624 non-null  int64
#  7   Dollar_Cost_Points_Redeemed  405624 non-null  int64
#  8   Date                         405624 non-null  period[M]
# dtypes: float64(1), int64(7), period[M](1)
# memory usage: 27.9 MB

# %% [markdown]
# ### Duplicados

# %%
df_vuelos.describe().T
# Out:
#                                 count           mean            std       min  \
# Loyalty_Number               405624.0  550037.873084  258935.286969  100018.0
# Flights_Booked               405624.0       4.115052       5.225518       0.0
# Flights_with_Companions      405624.0       1.031805       2.076869       0.0
# Total_Flights                405624.0       5.146858       6.521227       0.0
# Distance                     405624.0    1208.880059    1433.155320       0.0
# Points_Accumulated           405624.0     123.692721     146.599831       0.0
# Points_Redeemed              405624.0      30.696872     125.486049       0.0
# Dollar_Cost_Points_Redeemed  405624.0       2.484503      10.150038       0.0
#
#                                   25%       50%       75%       max
# Loyalty_Number               326961.0  550834.0  772194.0  999986.0
# Flights_Booked                    0.0       1.0       8.0      21.0
# Flights_with_Companions           0.0       0.0       1.0      11.0
# Total_Flights                     0.0       1.0      10.0      32.0
# Distance                          0.0     488.0    2336.0    6293.0
# Points_Accumulated                0.0      50.0     239.0     676.5
# Points_Redeemed                   0.0       0.0       0.0     876.0
# Dollar_Cost_Points_Redeemed       0.0       0.0       0.0      71.0

# %%
df_vuelos.columns
# Out:
# Index(['Loyalty_Number', 'Flights_Booked', 'Flights_with_Companions',
#        'Total_Flights', 'Distance', 'Points_Accumulated', 'Points_Redeemed',
#        'Dollar_Cost_Points_Redeemed', 'Date'],
#       dtype='object')

# %% [markdown]
# Ordenamos el DataFrame df_vuelos por la columna Loyalty_Number y luego por la columna Date, asegurando que los registros de cada cliente aparezcan en orden cronológico.

# %%
revision_datos= df_vuelos.sort_values(['Loyalty_Number','Date'])

# %%
revision_datos
# Out:
#         Loyalty_Number  Flights_Booked  Flights_with_Companions  \
# 0               100018               3                        0
# 16901           100018               2                        2
# 213311          100018              14                        3
# 50703           100018               4                        0
# 67604           100018               0                        0
# ...                ...             ...                      ...
# 140741          999986               8                        1
# 354920          999986               0                        0
# 371821          999986               6                        0
# 388722          999986              11                        4
# 405623          999986               0                        0
#
#         Total_Flights  Distance  Points_Accumulated  Points_Redeemed  \
# 0                   3      1521               152.0                0
# 16901               4      1320               132.0                0
# 213311             17      2533               253.0              438
# 50703               4       924                92.0                0
# 67604               0         0                 0.0                0
# ...               ...       ...                 ...              ...
# 140741              9      3672               367.0              655
# 354920              0         0                 0.0                0
# 371821              6       708                70.0                0
# 388722             15      2040               204.0                0
# 405623              0         0                 0.0                0
#
#         Dollar_Cost_Points_Redeemed     Date
# 0                                 0  2017-01
# 16901                             0  2017-02
# 213311                           36  2017-03
# 50703                             0  2017-04
# 67604                             0  2017-05
# ...                             ...      ...
# 140741                           53  2018-08
# 354920                            0  2018-09
# 371821                            0  2018-10
# 388722                            0  2018-11
# 405623                            0  2018-12
#
# [405624 rows x 9 columns]

# %% [markdown]
# Aquí vemos que los clientes se repiten muchas veces pero tienen datos de fecha diferentes

# %%
revision_datos.to_csv('revision_datos.csv')

# %% [markdown]
# Identificamos duplicados reales

# %%
df_vuelos[df_vuelos.duplicated(subset=['Loyalty_Number', 'Date'], keep=False)]
# Out:
#         Loyalty_Number  Flights_Booked  Flights_with_Companions  \
# 41              101902               0                        0
# 42              101902               0                        0
# 114             106001               9                        4
# 115             106001               5                        0
# 226             112142               0                        0
# ...                ...             ...                      ...
# 405437          989528               0                        0
# 405451          990512              15                        5
# 405452          990512               5                        2
# 405486          992168              15                        0
# 405487          992168               6                        0
#
#         Total_Flights  Distance  Points_Accumulated  Points_Redeemed  \
# 41                  0         0                 0.0                0
# 42                  0         0                 0.0                0
# 114                13      1365               136.0                0
# 115                 5       910                91.0                0
# 226                 0         0                 0.0                0
# ...               ...       ...                 ...              ...
# 405437              0         0                 0.0                0
# 405451             20      2940               294.0                0
# 405452              7      3906               390.0                0
# 405486             15      3120               312.0                0
# 405487              6      3192               319.0                0
#
#         Dollar_Cost_Points_Redeemed     Date
# 41                                0  2017-01
# 42                                0  2017-01
# 114                               0  2017-01
# 115                               0  2017-01
# 226                               0  2017-01
# ...                             ...      ...
# 405437                            0  2018-12
# 405451                            0  2018-12
# 405452                            0  2018-12
# 405486                            0  2018-12
# 405487                            0  2018-12
#
# [7848 rows x 9 columns]

# %% [markdown]
# Analizamos inconssistencias

# %%
df_vuelos[df_vuelos.duplicated(subset=['Loyalty_Number', 'Date'], keep=False)].sort_values(['Loyalty_Number', 'Date'])
# Out:
#         Loyalty_Number  Flights_Booked  Flights_with_Companions  \
# 41              101902               0                        0
# 42              101902               0                        0
# 16942           101902               0                        0
# 16943           101902               0                        0
# 33843           101902               0                        0
# ...                ...             ...                      ...
# 371685          992168               0                        0
# 130846          992168              11                        5
# 336313          992168               1                        1
# 405486          992168              15                        0
# 405487          992168               6                        0
#
#         Total_Flights  Distance  Points_Accumulated  Points_Redeemed  \
# 41                  0         0                 0.0                0
# 42                  0         0                 0.0                0
# 16942               0         0                 0.0                0
# 16943               0         0                 0.0                0
# 33843               0         0                 0.0                0
# ...               ...       ...                 ...              ...
# 371685              0         0                 0.0                0
# 130846             16      3360               336.0              502
# 336313              2       546                54.0              343
# 405486             15      3120               312.0                0
# 405487              6      3192               319.0                0
#
#         Dollar_Cost_Points_Redeemed     Date
# 41                                0  2017-01
# 42                                0  2017-01
# 16942                             0  2017-02
# 16943                             0  2017-02
# 33843                             0  2017-03
# ...                             ...      ...
# 371685                            0  2018-10
# 130846                           41  2018-11
# 336313                           28  2018-11
# 405486                            0  2018-12
# 405487                            0  2018-12
#
# [7848 rows x 9 columns]

# %%
df_vuelos.describe().T
# Out:
#                                 count           mean            std       min  \
# Loyalty_Number               405624.0  550037.873084  258935.286969  100018.0
# Flights_Booked               405624.0       4.115052       5.225518       0.0
# Flights_with_Companions      405624.0       1.031805       2.076869       0.0
# Total_Flights                405624.0       5.146858       6.521227       0.0
# Distance                     405624.0    1208.880059    1433.155320       0.0
# Points_Accumulated           405624.0     123.692721     146.599831       0.0
# Points_Redeemed              405624.0      30.696872     125.486049       0.0
# Dollar_Cost_Points_Redeemed  405624.0       2.484503      10.150038       0.0
#
#                                   25%       50%       75%       max
# Loyalty_Number               326961.0  550834.0  772194.0  999986.0
# Flights_Booked                    0.0       1.0       8.0      21.0
# Flights_with_Companions           0.0       0.0       1.0      11.0
# Total_Flights                     0.0       1.0      10.0      32.0
# Distance                          0.0     488.0    2336.0    6293.0
# Points_Accumulated                0.0      50.0     239.0     676.5
# Points_Redeemed                   0.0       0.0       0.0     876.0
# Dollar_Cost_Points_Redeemed       0.0       0.0       0.0      71.0

# %% [markdown]
# ### Toma de decisión

# %% [markdown]
# Aunque es cierto tenemos varias filas con datos 0 del mismo cliente que podríamos eliminar, en otros casos hay varias filas con el mismo cliente, pero recogen datos distintos cuando ordenamos por fecha. Por lo tanto, en este momento, no sé avanzar con algún método que me permita estudiar las filas de datos 0

# %% [markdown]
# ### CONCLUSIÓN
#
# NO ELIMINO DUPLICADOS. El valor 0 también es representativos en alguna estadística que se quiera obtener. Como por ejemplo, en qué meses el usuario no ha volado.

# %% [markdown]
# #### Útima revisión

# %%
df_vuelos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405624 entries, 0 to 405623
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Loyalty_Number               405624 non-null  int64
#  1   Flights_Booked               405624 non-null  int64
#  2   Flights_with_Companions      405624 non-null  int64
#  3   Total_Flights                405624 non-null  int64
#  4   Distance                     405624 non-null  int64
#  5   Points_Accumulated           405624 non-null  float64
#  6   Points_Redeemed              405624 non-null  int64
#  7   Dollar_Cost_Points_Redeemed  405624 non-null  int64
#  8   Date                         405624 non-null  period[M]
# dtypes: float64(1), int64(7), period[M](1)
# memory usage: 27.9 MB

# %%
df_vuelos['Distance'].sample(20)
# Out:
# 232910       0
# 160442       0
# 25243        0
# 342624       0
# 105949    3210
# 174779     792
# 12953        0
# 66892        0
# 190243     906
# 285478       0
# 375297    2630
# 3752         0
# 112197    4624
# 97234     5200
# 17807        0
# 9549         0
# 125560       0
# 17124     4708
# 380749    2680
# 144914       0
# Name: Distance, dtype: int64

# %%
df_vuelos['Points_Accumulated'].sample(20)
# Out:
# 248801    236.25
# 80520       0.00
# 232088      0.00
# 385140      0.00
# 289157      0.00
# 185991    285.00
# 204674      0.00
# 192662    414.00
# 85786     394.00
# 114288    187.00
# 352084      0.00
# 233250      0.00
# 34443     250.00
# 381296    106.00
# 291185    513.00
# 122468      0.00
# 287245    262.00
# 291186      0.00
# 149724    233.00
# 120533    264.00
# Name: Points_Accumulated, dtype: float64

# %% [markdown]
# Convertimos a int ya que todos los valores son enteros

# %%
df_vuelos['Points_Accumulated'] = df_vuelos['Points_Accumulated'].astype(int)

# %% [markdown]
# Comprobamos

# %%
df_vuelos['Points_Accumulated'].dtypes
# Out:
# dtype('int64')

# %%
df_vuelos.describe().T
# Out:
#                                 count           mean            std       min  \
# Loyalty_Number               405624.0  550037.873084  258935.286969  100018.0
# Flights_Booked               405624.0       4.115052       5.225518       0.0
# Flights_with_Companions      405624.0       1.031805       2.076869       0.0
# Total_Flights                405624.0       5.146858       6.521227       0.0
# Distance                     405624.0    1208.880059    1433.155320       0.0
# Points_Accumulated           405624.0     123.667002     146.579083       0.0
# Points_Redeemed              405624.0      30.696872     125.486049       0.0
# Dollar_Cost_Points_Redeemed  405624.0       2.484503      10.150038       0.0
#
#                                   25%       50%       75%       max
# Loyalty_Number               326961.0  550834.0  772194.0  999986.0
# Flights_Booked                    0.0       1.0       8.0      21.0
# Flights_with_Companions           0.0       0.0       1.0      11.0
# Total_Flights                     0.0       1.0      10.0      32.0
# Distance                          0.0     488.0    2336.0    6293.0
# Points_Accumulated                0.0      50.0     239.0     676.0
# Points_Redeemed                   0.0       0.0       0.0     876.0
# Dollar_Cost_Points_Redeemed       0.0       0.0       0.0      71.0

# %% [markdown]
# ### Limpieza finalizada

# %% [markdown]
# Guardamos el df limpio en un nuevo archivo

# %%
df_vuelos.to_csv('vuelos_limpio.csv')
